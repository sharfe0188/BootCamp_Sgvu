# %% [markdown]
# <center><h2>Machine Learning - Assignment - 6</h2></center>

# %% [markdown]
# ### Md Farid Ansari
# ### SID: 100477

# %% [markdown]
# # Random Forest Classifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data = pd.read_csv(r"C:\Users\farid\OneDrive\Desktop\Datasets\StressLevelDataset.csv")

# %%
# Features and target variable
X = data.drop('stress_level', axis=1) 
y = data['stress_level']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predictions and evaluation for Random Forest
y_pred_rf = rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)

# %%
print("Random Forest Accuracy: {:.2f}%".format(rf_accuracy * 100))
print("Classification Report (Random Forest):")
print(classification_report(y_test, y_pred_rf))
print("Confusion Matrix (Random Forest):")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 89.70%
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88       113
#            1       0.92      0.92      0.92       107
#            2       0.92      0.88      0.90       110
#
#     accuracy                           0.90       330
#    macro avg       0.90      0.90      0.90       330
# weighted avg       0.90      0.90      0.90       330
#
# Confusion Matrix (Random Forest):
# [[101   6   6]
#  [  6  98   3]
#  [ 10   3  97]]

# %% [markdown]
# # XGBoost Classifier

# %%
xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
xgb.fit(X_train, y_train)
# Out:
# C:\Users\farid\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:01:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
# ...

# %%
# Predictions and evaluation for XGBoost
y_pred_xgb = xgb.predict(X_test)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)

# %%
print("\nXGBoost Accuracy: {:.2f}%".format(xgb_accuracy * 100))
# Out:
# XGBoost Accuracy: 89.09%
