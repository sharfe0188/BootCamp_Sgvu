# %% [markdown]
# ### Name : - Md Sharfe Alam
# ### Sid : - 90749
# ### Day 06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
#Read and Understand the Dataset
import pandas as pd
df = pd.read_csv(r"C:\Users\mdsha\Desktop\All Dataset\Ice_cream selling data.csv")
df.head(10)
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531
# 5         -3.455712                30.001138
# 6         -3.108440                22.635401
# 7         -3.081303                25.365022
# 8         -2.672461                19.226970
# 9         -2.652287                20.279679

# %%
# Plot pairwise relationships in the dataset
sns.pairplot(df)

# %%
# Access the columns using the exact names with special characters
X = df[['Temperature (°C)']]  
y = df['Ice Cream Sales (units)']

# %%
y_pred = model.predict(X_test)

# %%
# Prepare the polynomial features (degree 2)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
# Split the polynomial data into training and testing sets
X_train_poly, X_test_poly, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

# %%
# Create a linear regression model for polynomial features
poly_model = LinearRegression()

# %%
# Train the polynomial model
poly_model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the polynomial model
y_poly_pred = poly_model.predict(X_test_poly)

# %%
# Evaluate the polynomial model
mse_poly = mean_squared_error(y_test, y_poly_pred)
r2_poly = r2_score(y_test, y_poly_pred)

# %%
print("Polynomial Regression (Degree 2)")
print("Mean Squared Error:", mse_poly)
print("R^2 Score:", r2_poly)
# Out:
# Polynomial Regression (Degree 2)
# Mean Squared Error: 14.878796440981484
# R^2 Score: 0.843055137193884

# %%
# Visualize the polynomial regression results
plt.scatter(X_test, y_test, color='blue', label='Actual Sales')  # Plot original points
plt.plot(X_test, y_poly_pred, color='red', linewidth=2, label='Predicted Sales')  # Plot polynomial regression line
plt.title('Polynomial Regression (Degree 2) - Temperature vs Ice Cream Sales')
plt.xlabel('Temperature (°C)')
plt.ylabel('Ice Cream Sales (units)')
plt.legend()
plt.show()
